# %%
import pandas as pd
from fbprophet import Prophet

# %%
url_sales = 'https://raw.githubusercontent.com/facebook/prophet/master/examples/example_retail_sales.csv'
df = pd.read_csv(url_sales)

# %%
# Prophet Model
m = Prophet()
m.fit(df)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods=365)

# %%
forecast = m.predict(future)
# forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(36)

# %%
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds           yhat     yhat_lower     yhat_upper
# 653 2017-04-27  493137.057228  482294.570846  503180.641837
# 654 2017-04-28  492460.325707  482021.821965  503147.288865
# 655 2017-04-29  492026.030777  480785.931655  502244.230798
# 656 2017-04-30  491859.098635  481174.128751  502154.966807
# 657 2017-05-01  491974.578441  481391.914533  502177.077266

# %%
fig1 = m.plot(forecast)

# %%
fig2 = m.plot_components(forecast)
